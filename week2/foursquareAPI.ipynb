# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#uncomment next line if need to install latest version of geopy
#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas import json_normalize

#uncomment next line if need to install latest version of folium
#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'ZVK5YKH5XQKTNS0OFJ552U5C2S1A51RBH3NPCFKIXW3UPZAC' # enter your Foursquare ID here!
CLIENT_SECRET = 'DDZFOTPDNSIPP1420QFCSVL2YCV2Z1PBUUUNKVJW3ZYOFWX5' # enter your Foursquare Secret here!

VERSION = '20180604' # what version of Foursquare you want to use
LIMIT = 30 # max limit is 50 
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ZVK5YKH5XQKTNS0OFJ552U5C2S1A51RBH3NPCFKIXW3UPZAC
# CLIENT_SECRET:DDZFOTPDNSIPP1420QFCSVL2YCV2Z1PBUUUNKVJW3ZYOFWX5

# %%
# Grand Central Terminal Address
address = '89 E 42nd St, New York, NY 10017'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print("The latitude and longitude coordinates are:")
print(latitude, longitude)
# Out:
# The latitude and longitude coordinates are:
# 40.7528064 -73.9771792

# %%
search_query = 'Pizza'
radius = 500 #Radius of search in meters

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '60dd3395f0348c0a142317b7'},
#  'response': {'venues': [{'id': '4d012c08ba1da1cd3cb68c28',
#     'name': '99¢ Fresh Pizza',
#     'location': {'address': '473 Lexington Ave',
#      'crossStreet': 'E 46th St',
#      'lat': 40.75377746512226,
#      'lng': -73.97438417198434,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75377746512226,
#        'lng': -73.97438417198434}],
#      'distance': 259,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['473 Lexington Ave (E 46th St)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2112242',
#      'url': 'https://www.seamless.com/menu/99-cent-fresh-pizza-473-lexington-ave-new-york/2112242?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2112242',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4a8c31aef964a520410d20e3',
#     'name': 'Little Italy Pizza',
#     'location': {'address': '55 W 45th St',
#      'crossStreet': 'at 5th Ave.',
#      'lat': 40.753781238005836,
#      'lng': -73.9798834675708,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.753781238005836,
#        'lng': -73.9798834675708}],
#      'distance': 252,
#      'postalCode': '10036',
#      'cc': 'US',
#      'neighborhood': 'Midtown East',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['55 W 45th St (at 5th Ave.)',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '65866',
#      'url': 'https://www.seamless.com/menu/little-italy-gourmet-pizza--pasta-55-w-45th-st-new-york/65866?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=65866',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4c7d96bbd65437043defc0a2',
#     'name': '2 Bros. Pizza',
#     'location': {'address': '31 W 46th St',
#      'crossStreet': 'btwn 5th & 6th Ave',
#      'lat': 40.75672851136888,
#      'lng': -73.98055343233084,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75672851136888,
#        'lng': -73.98055343233084},
#       {'label': 'entrance', 'lat': 40.756679, 'lng': -73.980303}],
#      'distance': 521,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['31 W 46th St (btwn 5th & 6th Ave)',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1292243',
#      'url': 'https://www.seamless.com/menu/2-bros-pizza-31-w-46th-st-new-york/1292243?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1292243',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4c0d749fd64c0f47a8be265d',
#     'name': '44th Street Pizza',
#     'location': {'address': '700 3rd Ave',
#      'crossStreet': '44th St',
#      'lat': 40.75205133446883,
#      'lng': -73.97374327909569,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75205133446883,
#        'lng': -73.97374327909569},
#       {'label': 'entrance', 'lat': 40.752012, 'lng': -73.973743}],
#      'distance': 301,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['700 3rd Ave (44th St)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '57fead01498e2e13f95505e3',
#     'name': 'Prova Pizzabar',
#     'location': {'address': '89 E 42nd St',
#      'crossStreet': 'Grand Central Terminal',
#      'lat': 40.752562395934845,
#      'lng': -73.97673104756964,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.752562395934845,
#        'lng': -73.97673104756964}],
#      'distance': 46,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['89 E 42nd St (Grand Central Terminal)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1704230',
#      'url': 'https://www.seamless.com/menu/prova-pizzabar-89-e-42nd-st-new-york/1704230?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1704230',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '438713796'},
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4fb14f77e4b0df0ef856f9d1',
#     'name': "Uncle Paul's Pizza",
#     'location': {'address': '70 Vanderbilt Ave',
#      'lat': 40.75469372075642,
#      'lng': -73.97687326007579,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75469372075642,
#        'lng': -73.97687326007579},
#       {'label': 'entrance', 'lat': 40.754698, 'lng': -73.976835}],
#      'distance': 211,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['70 Vanderbilt Ave',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '268082',
#      'url': 'https://www.seamless.com/menu/uncle-pauls-pizza-70-vanderbilt-ave-new-york/268082?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=268082',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '73165433'},
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '60aeb12170dbc03e3607d7f1',
#     'name': 'Upside Pizza',
#     'location': {'address': '20 E 40th St',
#      'lat': 40.751545,
#      'lng': -73.980591,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.751545,
#        'lng': -73.980591}],
#      'distance': 320,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['20 E 40th St',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '59b425432a7ab605019840c1',
#     'name': '99 Cents Fresh Pizza',
#     'location': {'address': '151 E 43rd St',
#      'lat': 40.75153897065933,
#      'lng': -73.97427436551119,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75153897065933,
#        'lng': -73.97427436551119},
#       {'label': 'entrance', 'lat': 40.751666, 'lng': -73.974272}],
#      'distance': 282,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['151 E 43rd St',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2112419',
#      'url': 'https://www.seamless.com/menu/99-cent-fresh-pizza-151-e-43rd-st-new-york/2112419?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2112419',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4af5bfc5f964a5204dfc21e3',
#     'name': 'Bravo Pizza',
#     'location': {'address': '6 E 42nd St',
#      'crossStreet': '5th Ave',
#      'lat': 40.75338586791304,
#      'lng': -73.98065810311275,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75338586791304,
#        'lng': -73.98065810311275},
#       {'label': 'entrance', 'lat': 40.753239, 'lng': -73.980698}],
#      'distance': 300,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['6 E 42nd St (5th Ave)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '5e724b1efbd6c000083825e4',
#     'name': 'Previti Pizza & Pasta',
#     'location': {'address': '341 Lexington Ave',
#      'crossStreet': 'btwn E 39th & 40th St',
#      'lat': 40.74969482421875,
#      'lng': -73.97703552246094,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.749748,
#        'lng': -73.977122},
#       {'label': 'display',
#        'lat': 40.74969482421875,
#        'lng': -73.97703552246094}],
#      'distance': 346,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['341 Lexington Ave (btwn E 39th & 40th St)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2038588',
#      'url': 'https://www.seamless.com/menu/previti-pasta--pizza-341-lexington-ave-new-york/2038588?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2038588',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '597a3082c824ae1e2f1e44d6',
#     'name': 'Stone Bridge Pizza & Salad',
#     'location': {'address': '16 E. 41 street',
#      'lat': 40.752585764935624,
#      'lng': -73.98045903500676,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.752585764935624,
#        'lng': -73.98045903500676}],
#      'distance': 277,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['16 E. 41 street',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '682406',
#      'url': 'https://www.seamless.com/menu/stone-bridge-pizza--salad-16-e-41st-st-new-york/682406?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=682406',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '458759928'},
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4b292c91f964a5204a9a24e3',
#     'name': 'Previti Pizza',
#     'location': {'address': '123 E 41st St.',
#      'crossStreet': 'btwn Lexington & Park Ave.',
#      'lat': 40.750894193875624,
#      'lng': -73.97662858745907,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.750894193875624,
#        'lng': -73.97662858745907}],
#      'distance': 217,
#      'postalCode': '10168',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['123 E 41st St. (btwn Lexington & Park Ave.)',
#       'New York, NY 10168',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '80350',
#      'url': 'https://www.seamless.com/menu/previti-pizza-123-e-41st-st-new-york/80350?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=80350',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '46360049'},
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4c3ddfeb83a3a5937140ed33',
#     'name': 'Pizza Place',
#     'location': {'lat': 40.75368157338077,
#      'lng': -73.9836141525577,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75368157338077,
#        'lng': -73.9836141525577}],
#      'distance': 551,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10018', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4f3218cf19836c91c7b581f8',
#     'name': 'Famous Original Rays Pizza',
#     'location': {'address': '686 3rd Ave',
#      'lat': 40.75176,
#      'lng': -73.97410500000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75176,
#        'lng': -73.97410500000001}],
#      'distance': 284,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['686 3rd Ave',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4c5c4659d25320a1dfb5c27a',
#     'name': "Original Ray's Pizza",
#     'location': {'address': '341 Lexington Ave',
#      'crossStreet': '39th',
#      'lat': 40.749691999999996,
#      'lng': -73.97703,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.749691999999996,
#        'lng': -73.97703}],
#      'distance': 346,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['341 Lexington Ave (39th)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4e4cd803bd413c4cc66c9d2c',
#     'name': "Domino's Pizza",
#     'location': {'address': '554 5th Ave',
#      'lat': 40.755881,
#      'lng': -73.97955,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.755881,
#        'lng': -73.97955},
#       {'label': 'entrance', 'lat': 40.755814, 'lng': -73.979393}],
#      'distance': 396,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['554 5th Ave',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4b54dc93f964a52032d027e3',
#     'name': 'Hot Hero Pizza',
#     'location': {'lat': 40.75311877092645,
#      'lng': -73.97228478066843,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75311877092645,
#        'lng': -73.97228478066843}],
#      'distance': 414,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10017', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4db19ab97abaff58538d458f',
#     'name': "Papa John's Pizza",
#     'location': {'address': '12 E 37th St',
#      'crossStreet': 'btwn Madison & 5th Ave.',
#      'lat': 40.749899158425436,
#      'lng': -73.98219863248106,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.749899158425436,
#        'lng': -73.98219863248106}],
#      'distance': 532,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['12 E 37th St (btwn Madison & 5th Ave.)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4ef5235d6c2507422701eeab',
#     'name': 'Getto Pizza',
#     'location': {'lat': 40.75563237459337,
#      'lng': -73.98029690811791,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75563237459337,
#        'lng': -73.98029690811791}],
#      'distance': 409,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10017', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '51b54bc4498e7bc653275562',
#     'name': 'Dollar Pizza',
#     'location': {'address': '34th and 3rd Ave',
#      'lat': 40.74856278340947,
#      'lng': -73.97508561960214,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74856278340947,
#        'lng': -73.97508561960214}],
#      'distance': 504,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['34th and 3rd Ave',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4e4cdebcbd413c4cc66cd4b2',
#     'name': "Nico's Pizza",
#     'location': {'address': '849 2nd Ave',
#      'lat': 40.75217056274414,
#      'lng': -73.97073364257812,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75217056274414,
#        'lng': -73.97073364257812}],
#      'distance': 548,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['849 2nd Ave',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '52af374e11d278d80ff061dd',
#     'name': 'raffaelo pizza',
#     'location': {'lat': 40.75704519896352,
#      'lng': -73.9803944749481,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75704519896352,
#        'lng': -73.9803944749481}],
#      'distance': 544,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '5da110df2c1e910008c61f82',
#     'name': 'New Balance Pizza Co',
#     'location': {'address': '47 E 34th St',
#      'lat': 40.747642,
#      'lng': -73.982298,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.747642,
#        'lng': -73.982298}],
#      'distance': 718,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['47 E 34th St',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '50f9918de4b06a4e33f7bc7b',
#     'name': "Patsy's Pizzeria",
#     'location': {'address': '801 2nd Ave',
#      'crossStreet': 'E. 42nd St.',
#      'lat': 40.75028472783832,
#      'lng': -73.97193065189576,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75028472783832,
#        'lng': -73.97193065189576}],
#      'distance': 524,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['801 2nd Ave (E. 42nd St.)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '294451',
#      'url': 'https://www.seamless.com/menu/patsys-pizzeria-801-2nd-ave-new-york/294451?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=294451',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '75702303'},
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4cadfc290c1e6dcb7d547abf',
#     'name': 'The Original Little Italy',
#     'location': {'address': '1 E 43rd st',
#      'lat': 40.754171,
#      'lng': -73.979794,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.754171,
#        'lng': -73.979794},
#       {'label': 'entrance', 'lat': 40.753972, 'lng': -73.97972}],
#      'distance': 267,
#      'postalCode': '10175',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1 E 43rd st',
#       'New York, NY 10175',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '450607',
#      'url': 'https://www.grubhub.com/restaurant/the-original-little-italy-1-e-43rd-st-new-york/450607?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=450607',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '510270624'},
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '506c968be4b088a79e51fe21',
#     'name': 'Dr. Bruce Lashley, D.P.M.',
#     'location': {'address': '353 Lexington Ave',
#      'crossStreet': '40th Street',
#      'lat': 40.749916,
#      'lng': -73.97683,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.749916,
#        'lng': -73.97683}],
#      'distance': 323,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['353 Lexington Ave (40th Street)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4b1ac3f7f964a5204df123e3',
#     'name': 'La Bellezza Pizzeria',
#     'location': {'address': '145 E 49th St',
#      'crossStreet': 'Between 3rd & Lexington',
#      'lat': 40.75566639798063,
#      'lng': -73.97217381762019,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75566639798063,
#        'lng': -73.97217381762019}],
#      'distance': 528,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['145 E 49th St (Between 3rd & Lexington)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '305958',
#      'url': 'https://www.seamless.com/menu/la-bellezza-145-e-49th-st-new-york/305958?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=305958',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4ad8a9fef964a520721321e3',
#     'name': 'Mondello Pizzeria & Restaurant',
#     'location': {'address': '3 E 37th St',
#      'crossStreet': 'btwn 5th and Madison',
#      'lat': 40.75024552836855,
#      'lng': -73.98287493096957,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75024552836855,
#        'lng': -73.98287493096957},
#       {'label': 'entrance', 'lat': 40.750159, 'lng': -73.982517}],
#      'distance': 558,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['3 E 37th St (btwn 5th and Madison)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False},
#    {'id': '4a7acb45f964a5207ce91fe3',
#     'name': 'Liberty Deli',
#     'location': {'address': '22 E 49th St',
#      'crossStreet': 'Madison Ave',
#      'lat': 40.757403738949435,
#      'lng': -73.97635133912335,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.757403738949435,
#        'lng': -73.97635133912335}],
#      'distance': 516,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['22 E 49th St (Madison Ave)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625109397',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a pandas dataframe
dataframe = json_normalize(venues)
dataframe
# Out:
#                           id                            name  \
# 0   4d012c08ba1da1cd3cb68c28                 99¢ Fresh Pizza
# 1   4a8c31aef964a520410d20e3              Little Italy Pizza
# 2   4c7d96bbd65437043defc0a2                   2 Bros. Pizza
# 3   4c0d749fd64c0f47a8be265d               44th Street Pizza
# 4   57fead01498e2e13f95505e3                  Prova Pizzabar
# 5   4fb14f77e4b0df0ef856f9d1              Uncle Paul's Pizza
# 6   60aeb12170dbc03e3607d7f1                    Upside Pizza
# 7   59b425432a7ab605019840c1            99 Cents Fresh Pizza
# 8   4af5bfc5f964a5204dfc21e3                     Bravo Pizza
# 9   5e724b1efbd6c000083825e4           Previti Pizza & Pasta
# 10  597a3082c824ae1e2f1e44d6      Stone Bridge Pizza & Salad
# 11  4b292c91f964a5204a9a24e3                   Previti Pizza
# 12  4c3ddfeb83a3a5937140ed33                     Pizza Place
# 13  4f3218cf19836c91c7b581f8      Famous Original Rays Pizza
# 14  4c5c4659d25320a1dfb5c27a            Original Ray's Pizza
# 15  4e4cd803bd413c4cc66c9d2c                  Domino's Pizza
# 16  4b54dc93f964a52032d027e3                  Hot Hero Pizza
# 17  4db19ab97abaff58538d458f               Papa John's Pizza
# 18  4ef5235d6c2507422701eeab                     Getto Pizza
# 19  51b54bc4498e7bc653275562                    Dollar Pizza
# 20  4e4cdebcbd413c4cc66cd4b2                    Nico's Pizza
# 21  52af374e11d278d80ff061dd                  raffaelo pizza
# 22  5da110df2c1e910008c61f82            New Balance Pizza Co
# 23  50f9918de4b06a4e33f7bc7b                Patsy's Pizzeria
# 24  4cadfc290c1e6dcb7d547abf       The Original Little Italy
# 25  506c968be4b088a79e51fe21       Dr. Bruce Lashley, D.P.M.
# 26  4b1ac3f7f964a5204df123e3            La Bellezza Pizzeria
# 27  4ad8a9fef964a520721321e3  Mondello Pizzeria & Restaurant
# 28  4a7acb45f964a5207ce91fe3                    Liberty Deli
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 1   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 2   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 3   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 4   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 5   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 6   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 7   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 8   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 9   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 10  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 11  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 12  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 13  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 14  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 15  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 16  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 17  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 18  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 19  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 20  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 21  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 22  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 23  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 24  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 25  [{'id': '4bf58dd8d48988d177941735', 'name': 'D...  v-1625109397    False
# 26  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 27  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1625109397    False
# 28  [{'id': '4bf58dd8d48988d146941735', 'name': 'D...  v-1625109397    False
#
#      location.address        location.crossStreet  location.lat  location.lng  \
# 0   473 Lexington Ave                   E 46th St     40.753777    -73.974384
# 1        55 W 45th St                 at 5th Ave.     40.753781    -73.979883
# 2        31 W 46th St          btwn 5th & 6th Ave     40.756729    -73.980553
# 3         700 3rd Ave                     44th St     40.752051    -73.973743
# 4        89 E 42nd St      Grand Central Terminal     40.752562    -73.976731
# 5   70 Vanderbilt Ave                         NaN     40.754694    -73.976873
# 6        20 E 40th St                         NaN     40.751545    -73.980591
# 7       151 E 43rd St                         NaN     40.751539    -73.974274
# 8         6 E 42nd St                     5th Ave     40.753386    -73.980658
# 9   341 Lexington Ave       btwn E 39th & 40th St     40.749695    -73.977036
# 10    16 E. 41 street                         NaN     40.752586    -73.980459
# 11     123 E 41st St.  btwn Lexington & Park Ave.     40.750894    -73.976629
# 12                NaN                         NaN     40.753682    -73.983614
# 13        686 3rd Ave                         NaN     40.751760    -73.974105
# 14  341 Lexington Ave                        39th     40.749692    -73.977030
# 15        554 5th Ave                         NaN     40.755881    -73.979550
# 16                NaN                         NaN     40.753119    -73.972285
# 17       12 E 37th St     btwn Madison & 5th Ave.     40.749899    -73.982199
# 18                NaN                         NaN     40.755632    -73.980297
# 19   34th and 3rd Ave                         NaN     40.748563    -73.975086
# 20        849 2nd Ave                         NaN     40.752171    -73.970734
# 21                NaN                         NaN     40.757045    -73.980394
# 22       47 E 34th St                         NaN     40.747642    -73.982298
# 23        801 2nd Ave                 E. 42nd St.     40.750285    -73.971931
# 24        1 E 43rd st                         NaN     40.754171    -73.979794
# 25  353 Lexington Ave                 40th Street     40.749916    -73.976830
# 26      145 E 49th St     Between 3rd & Lexington     40.755666    -73.972174
# 27        3 E 37th St        btwn 5th and Madison     40.750246    -73.982875
# 28       22 E 49th St                 Madison Ave     40.757404    -73.976351
#
#                               location.labeledLatLngs  ...  location.country  \
# 0   [{'label': 'display', 'lat': 40.75377746512226...  ...     United States
# 1   [{'label': 'display', 'lat': 40.75378123800583...  ...     United States
# 2   [{'label': 'display', 'lat': 40.75672851136888...  ...     United States
# 3   [{'label': 'display', 'lat': 40.75205133446883...  ...     United States
# 4   [{'label': 'display', 'lat': 40.75256239593484...  ...     United States
# 5   [{'label': 'display', 'lat': 40.75469372075642...  ...     United States
# 6   [{'label': 'display', 'lat': 40.751545, 'lng':...  ...     United States
# 7   [{'label': 'display', 'lat': 40.75153897065933...  ...     United States
# 8   [{'label': 'display', 'lat': 40.75338586791304...  ...     United States
# 9   [{'label': 'entrance', 'lat': 40.749748, 'lng'...  ...     United States
# 10  [{'label': 'display', 'lat': 40.75258576493562...  ...     United States
# 11  [{'label': 'display', 'lat': 40.75089419387562...  ...     United States
# 12  [{'label': 'display', 'lat': 40.75368157338077...  ...     United States
# 13  [{'label': 'display', 'lat': 40.75176, 'lng': ...  ...     United States
# 14  [{'label': 'display', 'lat': 40.74969199999999...  ...     United States
# 15  [{'label': 'display', 'lat': 40.755881, 'lng':...  ...     United States
# 16  [{'label': 'display', 'lat': 40.75311877092645...  ...     United States
# 17  [{'label': 'display', 'lat': 40.74989915842543...  ...     United States
# 18  [{'label': 'display', 'lat': 40.75563237459337...  ...     United States
# 19  [{'label': 'display', 'lat': 40.74856278340947...  ...     United States
# 20  [{'label': 'display', 'lat': 40.75217056274414...  ...     United States
# 21  [{'label': 'display', 'lat': 40.75704519896352...  ...     United States
# 22  [{'label': 'display', 'lat': 40.747642, 'lng':...  ...     United States
# 23  [{'label': 'display', 'lat': 40.75028472783832...  ...     United States
# 24  [{'label': 'display', 'lat': 40.754171, 'lng':...  ...     United States
# 25  [{'label': 'display', 'lat': 40.749916, 'lng':...  ...     United States
# 26  [{'label': 'display', 'lat': 40.75566639798063...  ...     United States
# 27  [{'label': 'display', 'lat': 40.75024552836855...  ...     United States
# 28  [{'label': 'display', 'lat': 40.75740373894943...  ...     United States
#
#                             location.formattedAddress delivery.id  \
# 0   [473 Lexington Ave (E 46th St), New York, NY 1...     2112242
# 1   [55 W 45th St (at 5th Ave.), New York, NY 1003...       65866
# 2   [31 W 46th St (btwn 5th & 6th Ave), New York, ...     1292243
# 3   [700 3rd Ave (44th St), New York, NY 10017, Un...         NaN
# 4   [89 E 42nd St (Grand Central Terminal), New Yo...     1704230
# 5   [70 Vanderbilt Ave, New York, NY 10017, United...      268082
# 6   [20 E 40th St, New York, NY 10016, United States]         NaN
# 7   [151 E 43rd St, New York, NY 10017, United Sta...     2112419
# 8   [6 E 42nd St (5th Ave), New York, NY 10017, Un...         NaN
# 9   [341 Lexington Ave (btwn E 39th & 40th St), Ne...     2038588
# 10  [16 E. 41 street, New York, NY 10017, United S...      682406
# 11  [123 E 41st St. (btwn Lexington & Park Ave.), ...       80350
# 12                [New York, NY 10018, United States]         NaN
# 13   [686 3rd Ave, New York, NY 10017, United States]         NaN
# 14  [341 Lexington Ave (39th), New York, NY 10016,...         NaN
# 15   [554 5th Ave, New York, NY 10036, United States]         NaN
# 16                [New York, NY 10017, United States]         NaN
# 17  [12 E 37th St (btwn Madison & 5th Ave.), New Y...         NaN
# 18                [New York, NY 10017, United States]         NaN
# 19  [34th and 3rd Ave, New York, NY 10016, United ...         NaN
# 20   [849 2nd Ave, New York, NY 10017, United States]         NaN
# 21                      [New York, NY, United States]         NaN
# 22  [47 E 34th St, New York, NY 10016, United States]         NaN
# 23  [801 2nd Ave (E. 42nd St.), New York, NY 10017...      294451
# 24   [1 E 43rd st, New York, NY 10175, United States]      450607
# 25  [353 Lexington Ave (40th Street), New York, NY...         NaN
# 26  [145 E 49th St (Between 3rd & Lexington), New ...      305958
# 27  [3 E 37th St (btwn 5th and Madison), New York,...         NaN
# 28  [22 E 49th St (Madison Ave), New York, NY 1001...         NaN
#
#                                          delivery.url delivery.provider.name  \
# 0   https://www.seamless.com/menu/99-cent-fresh-pi...               seamless
# 1   https://www.seamless.com/menu/little-italy-gou...               seamless
# 2   https://www.seamless.com/menu/2-bros-pizza-31-...               seamless
# 3                                                 NaN                    NaN
# 4   https://www.seamless.com/menu/prova-pizzabar-8...               seamless
# 5   https://www.seamless.com/menu/uncle-pauls-pizz...               seamless
# 6                                                 NaN                    NaN
# 7   https://www.seamless.com/menu/99-cent-fresh-pi...               seamless
# 8                                                 NaN                    NaN
# 9   https://www.seamless.com/menu/previti-pasta--p...               seamless
# 10  https://www.seamless.com/menu/stone-bridge-piz...               seamless
# 11  https://www.seamless.com/menu/previti-pizza-12...               seamless
# 12                                                NaN                    NaN
# 13                                                NaN                    NaN
# 14                                                NaN                    NaN
# 15                                                NaN                    NaN
# 16                                                NaN                    NaN
# 17                                                NaN                    NaN
# 18                                                NaN                    NaN
# 19                                                NaN                    NaN
# 20                                                NaN                    NaN
# 21                                                NaN                    NaN
# 22                                                NaN                    NaN
# 23  https://www.seamless.com/menu/patsys-pizzeria-...               seamless
# 24  https://www.grubhub.com/restaurant/the-origina...                grubhub
# 25                                                NaN                    NaN
# 26  https://www.seamless.com/menu/la-bellezza-145-...               seamless
# 27                                                NaN                    NaN
# 28                                                NaN                    NaN
#
#                delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 3                                        NaN                          NaN
# 4   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 5   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 6                                        NaN                          NaN
# 7   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 8                                        NaN                          NaN
# 9   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 10  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 11  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 12                                       NaN                          NaN
# 13                                       NaN                          NaN
# 14                                       NaN                          NaN
# 15                                       NaN                          NaN
# 16                                       NaN                          NaN
# 17                                       NaN                          NaN
# 18                                       NaN                          NaN
# 19                                       NaN                          NaN
# 20                                       NaN                          NaN
# 21                                       NaN                          NaN
# 22                                       NaN                          NaN
# 23  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 24  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 25                                       NaN                          NaN
# 26  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 27                                       NaN                          NaN
# 28                                       NaN                          NaN
#
#                  delivery.provider.icon.name location.neighborhood  \
# 0   /delivery_provider_seamless_20180129.png                   NaN
# 1   /delivery_provider_seamless_20180129.png          Midtown East
# 2   /delivery_provider_seamless_20180129.png                   NaN
# 3                                        NaN                   NaN
# 4   /delivery_provider_seamless_20180129.png                   NaN
# 5   /delivery_provider_seamless_20180129.png                   NaN
# 6                                        NaN                   NaN
# 7   /delivery_provider_seamless_20180129.png                   NaN
# 8                                        NaN                   NaN
# 9   /delivery_provider_seamless_20180129.png                   NaN
# 10  /delivery_provider_seamless_20180129.png                   NaN
# 11  /delivery_provider_seamless_20180129.png                   NaN
# 12                                       NaN                   NaN
# 13                                       NaN                   NaN
# 14                                       NaN                   NaN
# 15                                       NaN                   NaN
# 16                                       NaN                   NaN
# 17                                       NaN                   NaN
# 18                                       NaN                   NaN
# 19                                       NaN                   NaN
# 20                                       NaN                   NaN
# 21                                       NaN                   NaN
# 22                                       NaN                   NaN
# 23  /delivery_provider_seamless_20180129.png                   NaN
# 24   /delivery_provider_grubhub_20180129.png                   NaN
# 25                                       NaN                   NaN
# 26  /delivery_provider_seamless_20180129.png                   NaN
# 27                                       NaN                   NaN
# 28                                       NaN                   NaN
#
#    venuePage.id
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4     438713796
# 5      73165433
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10    458759928
# 11     46360049
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23     75702303
# 24    510270624
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
#
# [29 rows x 25 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                               name       categories            address  \
# 0                  99¢ Fresh Pizza      Pizza Place  473 Lexington Ave
# 1               Little Italy Pizza      Pizza Place       55 W 45th St
# 2                    2 Bros. Pizza      Pizza Place       31 W 46th St
# 3                44th Street Pizza      Pizza Place        700 3rd Ave
# 4                   Prova Pizzabar      Pizza Place       89 E 42nd St
# 5               Uncle Paul's Pizza      Pizza Place  70 Vanderbilt Ave
# 6                     Upside Pizza      Pizza Place       20 E 40th St
# 7             99 Cents Fresh Pizza      Pizza Place      151 E 43rd St
# 8                      Bravo Pizza      Pizza Place        6 E 42nd St
# 9            Previti Pizza & Pasta      Pizza Place  341 Lexington Ave
# 10      Stone Bridge Pizza & Salad      Pizza Place    16 E. 41 street
# 11                   Previti Pizza      Pizza Place     123 E 41st St.
# 12                     Pizza Place      Pizza Place                NaN
# 13      Famous Original Rays Pizza      Pizza Place        686 3rd Ave
# 14            Original Ray's Pizza      Pizza Place  341 Lexington Ave
# 15                  Domino's Pizza      Pizza Place        554 5th Ave
# 16                  Hot Hero Pizza      Pizza Place                NaN
# 17               Papa John's Pizza      Pizza Place       12 E 37th St
# 18                     Getto Pizza      Pizza Place                NaN
# 19                    Dollar Pizza      Pizza Place   34th and 3rd Ave
# 20                    Nico's Pizza      Pizza Place        849 2nd Ave
# 21                  raffaelo pizza      Pizza Place                NaN
# 22            New Balance Pizza Co      Pizza Place       47 E 34th St
# 23                Patsy's Pizzeria      Pizza Place        801 2nd Ave
# 24       The Original Little Italy      Pizza Place        1 E 43rd st
# 25       Dr. Bruce Lashley, D.P.M.  Doctor's Office  353 Lexington Ave
# 26            La Bellezza Pizzeria      Pizza Place      145 E 49th St
# 27  Mondello Pizzeria & Restaurant      Pizza Place        3 E 37th St
# 28                    Liberty Deli    Deli / Bodega       22 E 49th St
#
#                    crossStreet        lat        lng  \
# 0                    E 46th St  40.753777 -73.974384
# 1                  at 5th Ave.  40.753781 -73.979883
# 2           btwn 5th & 6th Ave  40.756729 -73.980553
# 3                      44th St  40.752051 -73.973743
# 4       Grand Central Terminal  40.752562 -73.976731
# 5                          NaN  40.754694 -73.976873
# 6                          NaN  40.751545 -73.980591
# 7                          NaN  40.751539 -73.974274
# 8                      5th Ave  40.753386 -73.980658
# 9        btwn E 39th & 40th St  40.749695 -73.977036
# 10                         NaN  40.752586 -73.980459
# 11  btwn Lexington & Park Ave.  40.750894 -73.976629
# 12                         NaN  40.753682 -73.983614
# 13                         NaN  40.751760 -73.974105
# 14                        39th  40.749692 -73.977030
# 15                         NaN  40.755881 -73.979550
# 16                         NaN  40.753119 -73.972285
# 17     btwn Madison & 5th Ave.  40.749899 -73.982199
# 18                         NaN  40.755632 -73.980297
# 19                         NaN  40.748563 -73.975086
# 20                         NaN  40.752171 -73.970734
# 21                         NaN  40.757045 -73.980394
# 22                         NaN  40.747642 -73.982298
# 23                 E. 42nd St.  40.750285 -73.971931
# 24                         NaN  40.754171 -73.979794
# 25                 40th Street  40.749916 -73.976830
# 26     Between 3rd & Lexington  40.755666 -73.972174
# 27        btwn 5th and Madison  40.750246 -73.982875
# 28                 Madison Ave  40.757404 -73.976351
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 40.75377746512226...       259      10017
# 1   [{'label': 'display', 'lat': 40.75378123800583...       252      10036
# 2   [{'label': 'display', 'lat': 40.75672851136888...       521      10036
# 3   [{'label': 'display', 'lat': 40.75205133446883...       301      10017
# 4   [{'label': 'display', 'lat': 40.75256239593484...        46      10017
# 5   [{'label': 'display', 'lat': 40.75469372075642...       211      10017
# 6   [{'label': 'display', 'lat': 40.751545, 'lng':...       320      10016
# 7   [{'label': 'display', 'lat': 40.75153897065933...       282      10017
# 8   [{'label': 'display', 'lat': 40.75338586791304...       300      10017
# 9   [{'label': 'entrance', 'lat': 40.749748, 'lng'...       346      10016
# 10  [{'label': 'display', 'lat': 40.75258576493562...       277      10017
# 11  [{'label': 'display', 'lat': 40.75089419387562...       217      10168
# 12  [{'label': 'display', 'lat': 40.75368157338077...       551      10018
# 13  [{'label': 'display', 'lat': 40.75176, 'lng': ...       284      10017
# 14  [{'label': 'display', 'lat': 40.74969199999999...       346      10016
# 15  [{'label': 'display', 'lat': 40.755881, 'lng':...       396      10036
# 16  [{'label': 'display', 'lat': 40.75311877092645...       414      10017
# 17  [{'label': 'display', 'lat': 40.74989915842543...       532      10016
# 18  [{'label': 'display', 'lat': 40.75563237459337...       409      10017
# 19  [{'label': 'display', 'lat': 40.74856278340947...       504      10016
# 20  [{'label': 'display', 'lat': 40.75217056274414...       548      10017
# 21  [{'label': 'display', 'lat': 40.75704519896352...       544        NaN
# 22  [{'label': 'display', 'lat': 40.747642, 'lng':...       718      10016
# 23  [{'label': 'display', 'lat': 40.75028472783832...       524      10017
# 24  [{'label': 'display', 'lat': 40.754171, 'lng':...       267      10175
# 25  [{'label': 'display', 'lat': 40.749916, 'lng':...       323      10016
# 26  [{'label': 'display', 'lat': 40.75566639798063...       528      10017
# 27  [{'label': 'display', 'lat': 40.75024552836855...       558      10016
# 28  [{'label': 'display', 'lat': 40.75740373894943...       516      10017
#
#     cc      city state        country  \
# 0   US  New York    NY  United States
# 1   US  New York    NY  United States
# 2   US  New York    NY  United States
# 3   US  New York    NY  United States
# 4   US  New York    NY  United States
# 5   US  New York    NY  United States
# 6   US  New York    NY  United States
# 7   US  New York    NY  United States
# 8   US  New York    NY  United States
# 9   US  New York    NY  United States
# 10  US  New York    NY  United States
# 11  US  New York    NY  United States
# 12  US  New York    NY  United States
# 13  US  New York    NY  United States
# 14  US  New York    NY  United States
# 15  US  New York    NY  United States
# 16  US  New York    NY  United States
# 17  US  New York    NY  United States
# 18  US  New York    NY  United States
# 19  US  New York    NY  United States
# 20  US  New York    NY  United States
# 21  US  New York    NY  United States
# 22  US  New York    NY  United States
# 23  US  New York    NY  United States
# 24  US  New York    NY  United States
# 25  US  New York    NY  United States
# 26  US  New York    NY  United States
# 27  US  New York    NY  United States
# 28  US  New York    NY  United States
#
#                                      formattedAddress  neighborhood  \
# 0   [473 Lexington Ave (E 46th St), New York, NY 1...           NaN
# 1   [55 W 45th St (at 5th Ave.), New York, NY 1003...  Midtown East
# 2   [31 W 46th St (btwn 5th & 6th Ave), New York, ...           NaN
# 3   [700 3rd Ave (44th St), New York, NY 10017, Un...           NaN
# 4   [89 E 42nd St (Grand Central Terminal), New Yo...           NaN
# 5   [70 Vanderbilt Ave, New York, NY 10017, United...           NaN
# 6   [20 E 40th St, New York, NY 10016, United States]           NaN
# 7   [151 E 43rd St, New York, NY 10017, United Sta...           NaN
# 8   [6 E 42nd St (5th Ave), New York, NY 10017, Un...           NaN
# 9   [341 Lexington Ave (btwn E 39th & 40th St), Ne...           NaN
# 10  [16 E. 41 street, New York, NY 10017, United S...           NaN
# 11  [123 E 41st St. (btwn Lexington & Park Ave.), ...           NaN
# 12                [New York, NY 10018, United States]           NaN
# 13   [686 3rd Ave, New York, NY 10017, United States]           NaN
# 14  [341 Lexington Ave (39th), New York, NY 10016,...           NaN
# 15   [554 5th Ave, New York, NY 10036, United States]           NaN
# 16                [New York, NY 10017, United States]           NaN
# 17  [12 E 37th St (btwn Madison & 5th Ave.), New Y...           NaN
# 18                [New York, NY 10017, United States]           NaN
# 19  [34th and 3rd Ave, New York, NY 10016, United ...           NaN
# 20   [849 2nd Ave, New York, NY 10017, United States]           NaN
# 21                      [New York, NY, United States]           NaN
# 22  [47 E 34th St, New York, NY 10016, United States]           NaN
# 23  [801 2nd Ave (E. 42nd St.), New York, NY 10017...           NaN
# 24   [1 E 43rd st, New York, NY 10175, United States]           NaN
# 25  [353 Lexington Ave (40th Street), New York, NY...           NaN
# 26  [145 E 49th St (Between 3rd & Lexington), New ...           NaN
# 27  [3 E 37th St (btwn 5th and Madison), New York,...           NaN
# 28  [22 E 49th St (Madison Ave), New York, NY 1001...           NaN
#
#                           id
# 0   4d012c08ba1da1cd3cb68c28
# 1   4a8c31aef964a520410d20e3
# 2   4c7d96bbd65437043defc0a2
# 3   4c0d749fd64c0f47a8be265d
# 4   57fead01498e2e13f95505e3
# 5   4fb14f77e4b0df0ef856f9d1
# 6   60aeb12170dbc03e3607d7f1
# 7   59b425432a7ab605019840c1
# 8   4af5bfc5f964a5204dfc21e3
# 9   5e724b1efbd6c000083825e4
# 10  597a3082c824ae1e2f1e44d6
# 11  4b292c91f964a5204a9a24e3
# 12  4c3ddfeb83a3a5937140ed33
# 13  4f3218cf19836c91c7b581f8
# 14  4c5c4659d25320a1dfb5c27a
# 15  4e4cd803bd413c4cc66c9d2c
# 16  4b54dc93f964a52032d027e3
# 17  4db19ab97abaff58538d458f
# 18  4ef5235d6c2507422701eeab
# 19  51b54bc4498e7bc653275562
# 20  4e4cdebcbd413c4cc66cd4b2
# 21  52af374e11d278d80ff061dd
# 22  5da110df2c1e910008c61f82
# 23  50f9918de4b06a4e33f7bc7b
# 24  4cadfc290c1e6dcb7d547abf
# 25  506c968be4b088a79e51fe21
# 26  4b1ac3f7f964a5204df123e3
# 27  4ad8a9fef964a520721321e3
# 28  4a7acb45f964a5207ce91fe3

# %%
venue_id = '4c7d96bbd65437043defc0a2' # ID of closest pizza joint
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
result['response']['venue']
print(result['response']['venue']['name'])
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 2 Bros. Pizza
# 5.8

# %%
venue_id = '4a8c31aef964a520410d20e3' # ID of second closest
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
print(result['response']['venue']['name'])
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# Little Italy Pizza
# 6.8

# %%
venue_id = '4d012c08ba1da1cd3cb68c28' # ID of third closest
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
print(result['response']['venue']['name'])
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 99¢ Fresh Pizza
# 6.5

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=16) # generate map centred around the Grand Central Terminal

# add a red circle marker to represent Grand Central Terminal
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Grand Central Terminal',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the pizza joints as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_fb99307693fb4ecca0bfbce43b1d6345%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fb99307693fb4ecca0bfbce43b1d6345%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fb99307693fb4ecca0bfbce43b1d6345%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_fb99307693fb4ecca0bfbce43b1d6345%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.7528064%2C%20-73.9771792%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
